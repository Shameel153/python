# %%
#celcius into fahrenheat
celcius=float(input("Enter temperature in celcius: "))
fahrenhiet = celcius*9/5+32
print("temperature in farenhiet:",round(fahrenhiet,3))
# Out:
# Enter temperature in celcius:  55
# temperature in farenhiet: 131.0

# %%
#kilometer into miles
km=float(input("Enter Distance in kilometers: "))
miles= km*0.62137
print("Distance in miles:",round(miles,2))
# Out:
# Enter Distance in kilometers:  10
# Distance in miles: 6.21
