# %%
#tuple
#third element and third element from last
a=input("enter the elements seperated by commas: ")
b=a.split(",")
print("Elements:",b)
print("3rd element:",b[2])
print("3rd element from last:",b[-3])
# Out:
# enter the elements seperated by commas:  10,20,30,40,60,70,65,90
# Elements: ['10', '20', '30', '40', '60', '70', '65', '90']
# 3rd element: 30
# 3rd element from last: 70

# %%
a=input("enter the numbers seperated by commas:")
b=a.split(",")
b=tuple(int(x)for x in b)
print("tupple:",b)
print("Average:",sum(b)/len(b))
# Out:
# enter the numbers seperated by commas: 10,40,50,70,30,47,59,40
# tupple: (10, 40, 50, 70, 30, 47, 59, 40)
# Average: 43.25
