# %%
#program to print all colors from colorset 1 not contained in color set 2
colorset1=set(input("enter colors in set1:").split(","))
colorset2=set(input("enter colors in set2:").split(","))
result=colorset1-colorset2
print("colors in set 1 but not in set 2 :",result)
# Out:
# enter colors in set1:blue,black,white
# enter colors in set2:orange,white
# colors in set 1 but not in set 2 : {'blue', 'black'}

# %%
#program to print all colors from set 1 and set 2
colorset1=set(input("enter colors in set 1:").split(","))
colorset2=set(input("enter colors in set2:").split(","))
result=colorset1|colorset2
print("colors in colorset1 and colorset2:",result)
# Out:
# enter colors in set 1:black,blue,white
# enter colors in set2:blue,red,orange
# colors in colorset1 and colorset2: {'red', 'blue', 'orange', 'white', 'black'}
