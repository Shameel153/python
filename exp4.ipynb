# %%
colors=input("Enter the name of colors seperated by comma:")
list=colors.split(",")
print("first color:",list[0])
print("last color:",list[-1])
# Out:
# Enter the name of colors seperated by comma: red,green,blue,orange
# first color: red
# last color: orange
